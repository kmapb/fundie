# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('data/sims.csv')
np.set_printoptions(precision=3, suppress=True)
np.set_printoptions(formatter={'float': '{: 0.3f}'.format})
print((data / 1e6).describe())
# Out:
#        distributions  distributions_to_lps  distributions_to_gps  \
# count  512000.000000         512000.000000         512000.000000
# mean      145.938137            144.221218              1.716919
# std       108.099095            106.827341              1.271754
# min         0.000000              0.000000              0.000000
# 25%        63.136866             62.394079              0.742787
# 50%       115.751663            114.389879              1.361784
# 75%       230.655347            227.941755              2.713592
# max       448.917468            443.636086              5.281382
#
#        carried_interest      fees_paid     dry_powder
# count     512000.000000  512000.000000  512000.000000
# mean          13.267783       9.659382      26.110215
# std           19.801201       2.586934      22.350026
# min            0.000000       2.550000       0.000000
# 25%            0.000000       7.650000       0.000000
# 50%            0.000000      10.200000      26.171037
# 75%           25.788837      12.750000      44.391477
# max           80.354367      12.750000      75.400000

# %%
data2 = pd.read_csv('data/sims-15plus.csv')

# %%
data2
# Out:
# Empty DataFrame
# Columns: [distributions, distributions_to_lps, distributions_to_gps, carried_interest, fees_paid, dry_powder]
# Index: []
